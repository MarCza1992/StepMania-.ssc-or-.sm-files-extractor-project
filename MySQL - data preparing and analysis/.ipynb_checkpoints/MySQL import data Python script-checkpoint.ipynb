# %%
import pandas as pd
from sqlalchemy import create_engine

user = 'root'
password = '<enter password>'
host = 'localhost'
port = 3306
database = 'itg_charts_data'
table_name = 'charts_data'
csv_path = r'<enter .csv path>'

engine = create_engine(f'mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}', echo=False)

print("Reading .csv file...")
df = pd.read_csv(csv_path, sep=';')

# import to MySQL
print(f"Import {len(df)} to '{table_name}' table...")
df.to_sql(name=table_name, con=engine, if_exists='append', index=False)

print("Import done ✅")
# Out:
# Wczytywanie danych z CSV...
# Importowanie 44647 wierszy do tabeli 'charts_data'...
# ✅ Import zakończony pomyślnie.
